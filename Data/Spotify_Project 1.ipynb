# %% [markdown]
# Spotipy API

# %%
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import matplotlib as plt

# %%
Client_ID = "c71bae50194549399a615967e53c6450"
Redirect_URI = "http://localhost:8080/callback/"
#Redirect_URI = "https://localhost:8282/callback"

# %%
with open('Spotify_secret_txt')as f:
    secret = f.readlines()[0]

# %%
secret
# Out:
# '20adff09ca8a475ab94c13cede1ee868'

# %%
# authorisation thing
sp_auth = spotipy.SpotifyOAuth(client_id = Client_ID,
                      client_secret = secret,
                      scope = 'user-read-recently-played,user-top-read',
                      redirect_uri = Redirect_URI)

# %%
# get authorizatgion 

#sp_auth.get_authorization_code()
sp_auth.get_auth_response()
# Out:
# 'AQD-fPbWlpZHSa2b9bGf16OUh7P4QppC5x-RKhQvz0af2yGDtVlBBsZBE11rnsfG3FdjF-clCPl2tXug9MI-_yDnxsyovWZMFGZQWbMqPppn885YDksaiGPbS_0Jh9DD7xAmqwsgzTj5QaCZMQxICxjmIAiUP1s9nEJyVzHi13ICt3Q3O98b7ZbHnqkhJWKCLGwzk8AnNogdSpnsq6hOJTnTxtOBdyCCAPyB3AQ'

# %%
# work with data
# extra access via "current_user_recently_played()"
sp = spotipy.Spotify(auth_manager = sp_auth)

# %%
my_top_songs = sp.current_user_top_tracks(limit = 50, time_range="long_term")

# %%
my_top_songs.keys()
# Out:
# dict_keys(['items', 'total', 'limit', 'offset', 'href', 'next', 'previous'])

# %%
my_top_songs['items']
# Out:
# [{'album': {'album_type': 'SINGLE',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7naAJDAh7AZnf18YYfQruM'},
#      'href': 'https://api.spotify.com/v1/artists/7naAJDAh7AZnf18YYfQruM',
#      'id': '7naAJDAh7AZnf18YYfQruM',
#      'name': 'Christian French',
#      'type': 'artist',
#      'uri': 'spotify:artist:7naAJDAh7AZnf18YYfQruM'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
# ...

# %%
my_top_songs['items'][0].keys()
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %%
my_top_songs['items']
# Out:
# [{'album': {'album_type': 'SINGLE',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7naAJDAh7AZnf18YYfQruM'},
#      'href': 'https://api.spotify.com/v1/artists/7naAJDAh7AZnf18YYfQruM',
#      'id': '7naAJDAh7AZnf18YYfQruM',
#      'name': 'Christian French',
#      'type': 'artist',
#      'uri': 'spotify:artist:7naAJDAh7AZnf18YYfQruM'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
# ...

# %%
dl_top = []
    
    for item in my_top_songs["items"]:
        d = {}
        d["track_title"] = item["name"]
        da = []
        for artist in item["artists"]:
            da.append(artist["name"])
        d["artists"] = da
        d["popularity"] = item["popularity"]
        d["uri"] = item["uri"]
        d["duration"] = item["duration_ms"]
        dl_top.append(d)
    my_top_songs_df = pd.DataFrame(dl_top)
# Out:
#   File "/var/folders/8f/9zw_p6792hn20w3nx0r0lzkr0000gn/T/ipykernel_17732/307456701.py", line 3
#     for item in my_top_songs["items"]:
#     ^
# IndentationError: unexpected indent
